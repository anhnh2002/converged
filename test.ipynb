# %%
from thucchien_ai_sdk import ThucChienClient, TextGenerator, ImageGenerator

# Initialize client
client = ThucChienClient()

# Text Generation
generator = TextGenerator(client)
response = generator.generate("Hello")
print(response)
# Out:
# Hello! How can I help you today?

# %%
from thucchien_ai_sdk import ThucChienClient, TextGenerator, ImageGenerator

client = ThucChienClient()

# Image Generation
img_generator = ImageGenerator(client)
result = img_generator.text_to_image(
    prompt="A serene mountain landscape at sunset",
    save_path="outputs/mountain-2.png"
)
# Out:
# Image saved to: outputs/mountain-2.png

# %%
from thucchien_ai_sdk import ThucChienClient, TextGenerator, ImageGenerator

client = ThucChienClient()

# Image Generation
img_generator = ImageGenerator(client)
result = img_generator.chat_generate_image(
    prompt="A serene mountain landscape at Vietnam spring",
    save_path="outputs/mountain-4.png",
    aspect_ratio="16:9"
)
# Out:
# data:  {'model': 'gemini-2.5-flash-image-preview', 'messages': [{'role': 'user', 'content': 'A serene mountain landscape at Vietnam spring'}], 'generationConfig': {'modalities': ['text', 'image'], 'imageConfig': {'aspectRatio': '16:9'}}}
# Image saved to: outputs/mountain-4.png

# %%
# Out:
# Starting video generation with prompt: A serene mountain landscape at Vietnam spring...
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[4], line 104
#     100     client.close()
#     102     return f"Video generation successful! Saved to: {save_path}"
# --> 104 text_to_video(
#     105     prompt="A serene mountain landscape at Vietnam spring",
#     106     save_path="outputs/mountain-4.mp4",
#     107     aspect_ratio="16:9",
#     108     duration_seconds=4,
#     109     resolution="1080p",
#     110 )
#
# Cell In[4], line 67, in text_to_video(prompt, model, aspect_ratio, negative_prompt, person_generation, duration_seconds, resolution, generate_audio, save_path, poll_interval)
#      64 print(f"Starting video generation with prompt: {prompt[:100]}...")
#      66 # Start video generation (async operation)
# ---> 67 operation = client.models.generate_videos(
# ...

# %%
# Out:
# 🚀 Starting Veo Video Generation Example
# 🎬 Using prompt: 'A cat playing with a ball of yarn in a sunny garden'
# ...
# 🎬 VEO VIDEO GENERATION WORKFLOW
# ...
# 🎬 Generating video with prompt: 'A cat playing with a ball of yarn in a sunny garden'
# ✅ Video generation started: models/veo-3.0-generate-preview/operations/hc6ki9kyxxut
# ⏳ Waiting for video generation to complete...
# 🔍 Polling status... (0s elapsed)
# 🔍 Polling status... (10s elapsed)
# 🔍 Polling status... (22s elapsed)
# 🔍 Polling status... (37s elapsed)
# 🔍 Polling status... (55s elapsed)
# 🔍 Polling status... (76s elapsed)
# 🎉 Video generation complete!
# 📹 Video URI: https://generativelanguage.googleapis.com/v1beta/files/pvco5n7ps75t:download?alt=media
# ⬇️  Downloading video...
# Original URI: https://generativelanguage.googleapis.com/v1beta/files/pvco5n7ps75t:download?alt=media
# Download URL: https://api.thucchien.ai/gemini/download/v1beta/files/pvco5n7ps75t:download?alt=media
# 📦 Downloaded 1.0 MB...
# 📦 Downloaded 2.0 MB...
# ...

# %%
x = []
y = [1, *x, 3]
y
# Out:
# [1, 3]
